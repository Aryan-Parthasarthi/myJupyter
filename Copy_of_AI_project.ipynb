# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryan-Parthasarthi/myJupyter/blob/main/Copy_of_AI_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![m.png](data:image/png;base64,...)

# %% [markdown]
# # ***Fragility Index - m***
#
# ---
#
#
#
# ---

# %%
dfm=pd.read_csv('/content/drive/MyDrive/semm_2/m.csv')

# %%
dfm.describe()
# Out:
#                Li          Na          Ca          Si           B          Al  \
# count  937.000000  937.000000  937.000000  937.000000  937.000000  937.000000
# mean     0.009194    0.084379    0.019098    0.198040    0.052643    0.036130
# std      0.033748    0.065756    0.029988    0.070362    0.099986    0.040259
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.022200    0.000000    0.197531    0.000000    0.000000
# 50%      0.000000    0.090283    0.000091    0.213115    0.000000    0.014269
# 75%      0.000000    0.111938    0.030471    0.241497    0.058701    0.066505
# max      0.222200    0.280000    0.201280    0.333333    0.400000    0.163287
#
#                 O           m
# count  937.000000  937.000000
# mean     0.597894   35.971933
# std      0.026213   10.151961
# min      0.526667   18.221299
# 25%      0.584154   28.694240
# 50%      0.600439   34.739657
# 75%      0.612676   40.028747
# ...

# %%
# Split the data into independent (X) and dependent (y) variables
X_train, X_test, y_train, y_test = train_test_split(dfm.iloc[:, :-1].values, dfm.iloc[:, -1].values, test_size=0.2)

# %% [markdown]
# ##**Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# create a Random Forest model
model = RandomForestRegressor()

# train the model on the training data
model.fit(X_train, y_train)

# make predictions on the test data
y_pred = model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_rf))
print("R-squared score: {:.2f}".format(r2_rf))
# Out:
# Mean squared error: 32.64
# R-squared score: 0.66

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

# %%
# create linear regression model
lr = LinearRegression()

# fit the model to the training data
lr.fit(X_train, y_train)

# make predictions on the test data
y_pred = lr.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_lr = mean_squared_error(y_test, y_pred)
r2_lr = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_lr))
print("R-squared score: {:.2f}".format(r2_lr))
# Out:
# Mean squared error: 46.36
# R-squared score: 0.52

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Support Vector Regression**

# %%
from sklearn.svm import SVR

# create SVR model
svr = SVR(kernel='rbf')

# fit the model to the training data
svr.fit(X_train, y_train)

# make predictions on the test data
y_pred = svr.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_svr = mean_squared_error(y_test, y_pred)
r2_svr = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_svr))
print("R-squared score: {:.2f}".format(r2_svr))
# Out:
# Mean squared error: 56.22
# R-squared score: 0.41

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ## **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor


# create gradient boosting regressor model with 100 trees
gb = GradientBoostingRegressor(n_estimators=100, random_state=42)

# fit the model to the training data
gb.fit(X_train, y_train)

# make predictions on the test data
y_pred = gb.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_gb = mean_squared_error(y_test, y_pred)
r2_gb = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_gb))
print("R-squared score: {:.2f}".format(r2_gb))
# Out:
# Mean squared error: 34.46
# R-squared score: 0.64

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ## **Neural Networks**

# %%
from sklearn.neural_network import MLPRegressor


# create MLP regressor model with 2 hidden layers of 10 neurons each
mlp = MLPRegressor(hidden_layer_sizes=(10, 10), max_iter=1000, random_state=42)

# fit the model to the training data
mlp.fit(X_train, y_train)

# make predictions on the test data
y_pred = mlp.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_nn = mean_squared_error(y_test, y_pred)
r2_nn = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_nn))
print("R-squared score: {:.2f}".format(r2_nn))
# Out:
# Mean squared error: 54.22
# R-squared score: 0.44
# /usr/local/lib/python3.9/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Bayesian Regression**

# %%
from sklearn.linear_model import BayesianRidge

# create Bayesian ridge regression model
br = BayesianRidge()

# fit the model to the training data
br.fit(X_train, y_train)

# make predictions on the test data
y_pred = br.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_br = mean_squared_error(y_test, y_pred)
r2_br = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_br))
print("R-squared : {:.2f}".format(r2_br))
# Out:
# Mean squared error: 46.08
# R-squared : 0.52

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# # Comparisions

# %%
models=["Random Forest","Linear","SVR","Gradient","Neural","Bayesian"]
mse=[mse_rf,mse_lr,mse_svr,mse_gb,mse_nn,mse_br]
r2=[r2_rf,r2_lr,r2_svr,r2_gb,r2_nn,r2_br]

# %%
for a,b,c in zip(models,mse,r2):
  print(a, " rmse= ",b," r2= ",c)
# Out:
# Random Forest  rmse=  32.64473703946786  r2=  0.6598573065064643
# Linear  rmse=  46.36485212594198  r2=  0.5169002076359055
# SVR  rmse=  56.2184044513947  r2=  0.41423086083103333
# Gradient  rmse=  34.4610123259196  r2=  0.6409325785384454
# Neural  rmse=  54.21844930875648  r2=  0.43506944587648044
# Bayesian  rmse=  46.08498767624268  r2=  0.5198162626073

# %%
import matplotlib.pyplot as plt
import numpy as np

# define the models and their corresponding MSE and R-squared values
models = ["Random Forest", "Linear", "SVR", "Gradient", "Neural", "Bayesian"]
mse = [mse_rf, mse_lr, mse_svr, mse_gb, mse_nn, mse_br]
r2 = [r2_rf, r2_lr, r2_svr, r2_gb, r2_nn, r2_br]

# create a figure with two subplots side-by-side
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

# plot the MSE values in the left subplot
ax1.bar(models, mse, color='b')
ax1.set_title('Mean Squared Error')
ax1.set_xlabel('Regression Model')
ax1.set_ylabel('MSE')

# plot the R-squared values in the right subplot
ax2.bar(models, r2, color='g')
ax2.set_title('R-squared Score')
ax2.set_xlabel('Regression Model')
ax2.set_ylabel('R-squared')

# adjust the layout of the subplots
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# ![tl.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # ***Liquidus Temperature - Tl***
#
# ---
#
#
#
#
#
#
# ---
# The best performing metric for glass-forming ability is simply the liquidus viscosity, where a higher viscosity at the liquidus temperature enables easier vitrification. This result is intuitive since it was the only metric that accounted for both thermodynamic and kinetic effects.

# %%
dft=pd.read_csv('/content/drive/MyDrive/semm_2/tl.csv')

# %%
dft.describe()
# Out:
#                 Li           Na           Ca           Si            B  \
# count  3871.000000  3871.000000  3871.000000  3871.000000  3871.000000
# mean      0.028540     0.081035     0.031744     0.165724     0.058058
# std       0.075643     0.099659     0.054077     0.086697     0.104535
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.130248     0.000000
# 50%       0.000000     0.057269     0.000000     0.200000     0.000000
# 75%       0.000000     0.125992     0.037708     0.222233     0.060195
# max       0.666667     0.666667     0.500000     0.333333     0.400000
#
#                 Al            O    Tliquidus
# count  3871.000000  3871.000000  3871.000000
# mean      0.050488     0.582741  1387.814066
# std       0.070782     0.047731   294.378218
# min       0.000000     0.333333   673.150000
# 25%       0.000000     0.555633  1177.150000
# 50%       0.027679     0.592360  1349.150000
# ...

# %%
# Split the data into independent (X) and dependent (y) variables
X_train, X_test, y_train, y_test = train_test_split(dft.iloc[:, :-1].values, dft.iloc[:, -1].values, test_size=0.2)

# %% [markdown]
# ##**Random Forrest**

# %%
from sklearn.ensemble import RandomForestRegressor

# create a Random Forest model
model = RandomForestRegressor()

# train the model on the training data
model.fit(X_train, y_train)

# make predictions on the test data
y_pred = model.predict(X_test)

mse_rf = mean_squared_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_rf))
print("R-squared score: {:.2f}".format(r2_rf))
# Out:
# Mean squared error: 2831.03
# R-squared score: 0.96

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Linear Regression**

# %%
from sklearn.linear_model import LinearRegression

# create linear regression model
lr = LinearRegression()

# fit the model to the training data
lr.fit(X_train, y_train)

# make predictions on the test data
y_pred = lr.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_lr = mean_squared_error(y_test, y_pred)
r2_lr = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_lr))
print("R-squared score: {:.2f}".format(r2_lr))
# Out:
# Mean squared error: 27471.64
# R-squared score: 0.65

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Support Vector Regression**

# %%
from sklearn.svm import SVR

# create SVR model
svr = SVR(kernel='rbf')

# fit the model to the training data
svr.fit(X_train, y_train)

# make predictions on the test data
y_pred = svr.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_svr = mean_squared_error(y_test, y_pred)
r2_svr = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_svr))
print("R-squared score: {:.2f}".format(r2_svr))
# Out:
# Mean squared error: 49155.55
# R-squared score: 0.37

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor


# create gradient boosting regressor model with 100 trees
gb = GradientBoostingRegressor(n_estimators=100, random_state=42)

# fit the model to the training data
gb.fit(X_train, y_train)

# make predictions on the test data
y_pred = gb.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_gb = mean_squared_error(y_test, y_pred)
r2_gb = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_gb))
print("R-squared score: {:.2f}".format(r2_gb))
# Out:
# Mean squared error: 5362.57
# R-squared score: 0.93

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ## **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingRegressor


# create gradient boosting regressor model with 100 trees
gb = GradientBoostingRegressor(n_estimators=100, random_state=42)

# fit the model to the training data
gb.fit(X_train, y_train)

# make predictions on the test data
y_pred = gb.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_gb = mean_squared_error(y_test, y_pred)
r2_gb = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_gb))
print("R-squared score: {:.2f}".format(r2_gb))
# Out:
# Mean squared error: 5362.57
# R-squared score: 0.93

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ##**Neural Network**

# %%
from sklearn.neural_network import MLPRegressor


# create MLP regressor model with 2 hidden layers of 10 neurons each
mlp = MLPRegressor(hidden_layer_sizes=(10, 10), max_iter=1000, random_state=42)

# fit the model to the training data
mlp.fit(X_train, y_train)

# make predictions on the test data
y_pred = mlp.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_nn = mean_squared_error(y_test, y_pred)
r2_nn = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_nn))
print("R-squared score: {:.2f}".format(r2_nn))
# Out:
# Mean squared error: 28969.16
# R-squared score: 0.63

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# ## **Bayesian Regression**

# %%
from sklearn.linear_model import BayesianRidge

# create Bayesian ridge regression model
br = BayesianRidge()

# fit the model to the training data
br.fit(X_train, y_train)

# make predictions on the test data
y_pred = br.predict(X_test)

# calculate and print the mean squared error and R-squared score
mse_br = mean_squared_error(y_test, y_pred)
r2_br = r2_score(y_test, y_pred)
print("Mean squared error: {:.2f}".format(mse_br))
print("R-squared : {:.2f}".format(r2_br))
# Out:
# Mean squared error: 27478.50
# R-squared : 0.65

# %%
# create scatter plot of predicted vs. actual values
sns.scatterplot(x=y_pred, y=y_test)
plt.xlabel("Predicted Values")
plt.ylabel("Actual Values")
plt.title("Predicted vs. Actual Values")
plt.show()

# %%
# create residual plot
residuals = y_test - y_pred
sns.residplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# %%
# create distribution plot of residuals
sns.histplot(residuals, kde=True)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Distribution of Residuals")
plt.show()

# %% [markdown]
# # Comparisions

# %%
models=["Random Forest","Linear","SVR","Gradient","Neural","Bayesian"]
mse=[mse_rf,mse_lr,mse_svr,mse_gb,mse_nn,mse_br]
r2=[r2_rf,r2_lr,r2_svr,r2_gb,r2_nn,r2_br]

# %%
for a,b,c in zip(models,mse,r2):
  print(a, " rmse= ",b," r2= ",c)
# Out:
# Random Forest  rmse=  2831.0256767459946  r2=  0.9635480883148184
# Linear  rmse=  27471.638994246463  r2=  0.6462788145332283
# SVR  rmse=  49155.545902283266  r2=  0.3670797009066886
# Gradient  rmse=  5362.568601121586  r2=  0.9309522768869785
# Neural  rmse=  28969.158126624312  r2=  0.6269969565095843
# Bayesian  rmse=  27478.49969812607  r2=  0.6461904770186759

# %%
import numpy as np

# define the models and their corresponding MSE and R-squared values
models = ["Random Forest", "Linear", "SVR", "Gradient", "Neural", "Bayesian"]
mse = [mse_rf, mse_lr, mse_svr, mse_gb, mse_nn, mse_br]
r2 = [r2_rf, r2_lr, r2_svr, r2_gb, r2_nn, r2_br]

# create a figure with two subplots side-by-side
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 6))

# plot the MSE values in the left subplot
ax1.bar(models, mse, color='b')
ax1.set_title('Mean Squared Error - Temperature Fahrenheit')
ax1.set_xlabel('Regression Model')
ax1.set_ylabel('MSE')

# plot the R-squared values in the right subplot
ax2.bar(models, r2, color='g')
ax2.set_title('R-squared Score')
ax2.set_xlabel('Regression Model')
ax2.set_ylabel('R-squared')

# adjust the layout of the subplots
plt.tight_layout()

# show the plot
plt.show()

# %% [markdown]
# # ***Findings and Conclusions***
#
#
# ---
#
#
# > *The paper concluded that a universal parameter for glass-forming ability that is quantitatively predictive from modeling wasn't achieved although using a combination of a using machine learning models enabled a quantitative prediction of the
# compositional dependencies of critical quench rates such as Liquidus temperature and Fragility index*
#
#  We found that :
#
# *   For such chemical compositions based prediction worked best with Random Forest regression based model in comparision to others.
# *   We worked on six models : "Random Forest", "Linear Regression", "SVR", "Gradient", "Neural", "Bayesian"

# %% [markdown]
# #***Future Work***
#
#
# ---
#
#
# 1.   Try to combine the physics based model with our ML model.
# 2.   The physics-based component of the approach involves the use of a thermodynamic model to calculate the critical cooling rate required to form a glass from a given composition.

# %% [markdown]
# Testing

# %%
dfm.sort_values('m')
# Out:
#       Li        Na        Ca        Si         B        Al         O  \
# 1    0.0  0.000000  0.000000  0.333333  0.000000  0.000000  0.666667
# 920  0.0  0.061091  0.000000  0.256707  0.000000  0.055297  0.626905
# 921  0.0  0.061091  0.000000  0.256707  0.000000  0.055297  0.626905
# 244  0.0  0.086797  0.000000  0.213020  0.022005  0.066015  0.606968
# 247  0.0  0.074449  0.000000  0.200119  0.035736  0.073258  0.607207
# ..   ...       ...       ...       ...       ...       ...       ...
# 398  0.0  0.136364  0.000000  0.000000  0.272727  0.045455  0.545455
# 375  0.0  0.117124  0.000311  0.148925  0.147934  0.002832  0.582873
# 403  0.0  0.145056  0.000000  0.000000  0.290066  0.022901  0.541978
# 401  0.0  0.153669  0.000000  0.000000  0.307799  0.000000  0.538532
# 743  0.0  0.026742  0.088656  0.199926  0.000000  0.073119  0.611557
#
#               m
# 1     18.221299
# 920   18.415848
# 921   18.424787
# 244   18.512520
# 247   18.773018
# ..          ...
# ...
